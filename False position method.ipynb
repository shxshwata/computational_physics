# %%
#Importing required libraries
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def f(x): #To find the value of f(x) given in the problem
       return x**3-x-1

# %%
a=1
b=2
tol=0.001
error=abs(a-b)


#n=10

while(error>tol):
#for i in range(n):
    c= a-((b-a)*f(a))/(f(b)-f(a)) #False position method
    #print("c =",c)
    if((f(a)*f(c))<0):
        b=c
    else:
        a=c

    error=abs(a-b)

print("The root of the given equation is ",c)
# Out:
# The root of the given equation is  1.324717957244746
