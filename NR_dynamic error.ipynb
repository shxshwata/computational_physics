# %%
#Importing required libraries
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
def f1(x):
    return np.tan(x)-x

# %%
def df1(x):
    sec_x = 1/np.cos(x)
    secx_sqr = sec_x**2
    return secx_sqr - 1

# %%
x0 = float(input("Enter the starting value ="))
err_prev=1

n=20
tol=0.01
flag =0

while(error>tol):
#for i in range (n):
  x1 = x0 - (f1(x0)/df1(x0))
  err_current = abs(x1-x0)
  print(x1)
  #print(err_current)
  if(err_current > err_prev):
    flag+=1;
    if(flag>3):
      print("The given starting point diverges")
      break
  err_prev=err_current
  x0=x1

print("The root is =", x1)
# Out:
# Enter the starting value =7.5
# 8.154691553532398
# 9.249049536617886
# 308.2452596205605
# 2364.65403430296
# 3498.787538836191
# 5314.01376205931
# The given starting point diverges
# The root is = 5314.01376205931
