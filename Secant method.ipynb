# %%
#Importing required libraries
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def f(x): #To find the value of f(x) given in the problem
    return x**3-5*x

# %%
x0 = float(input("Enter the starting value ="))
x1 = float(input("Enter the starting value ="))

n=20
tol=0.01
error = x0

while(error>tol):
#for i in range (n):
  xi = x1 - (f(x1)*(x1-x0))/(f(x1)-f(x0))
  print(xi)
  error = abs(xi-x1)

  x0=x1
  x1=xi

print("The root is =", xi)
# Out:
# Enter the starting value =1.5
# Enter the starting value =2
# 2.4705882352941178
# 2.1991043747847057
# 2.23080425320513
# 2.236201434100699
# The root is = 2.236201434100699
